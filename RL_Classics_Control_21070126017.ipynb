# %% [markdown]
# # Anvesha Raikwar
# ## AIML A1
# ### 21070126017

# %%
# Import necessary libraries
import gym  # OpenAI Gym library for reinforcement learning environments
import numpy as np  # NumPy library for numerical computations
from IPython import display  # IPython library for interactive computing
from matplotlib import pyplot as plt  # Matplotlib library for data visualization
# %matplotlib inline

# %%
def test_env(env: gym.Env) -> None:
     # Reset the environment
    env.reset()

    # Initializing variables
    done = False

    # Displaying initial environment state
    img = plt.imshow(env.render(mode='rgb_array'))

    # Loop until episode termination
    while not done:
        # Selecting a random action
        action = env.action_space.sample()

        # Taking a step in the environment
        obs, reward, done, info = env.step(action)

        # Updating the displayed image
        img.set_data(env.render(mode='rgb_array'))

        # Displaying the updated image
        display.display(plt.gcf())

        # the previous display will be cleared
        display.clear_output(wait=True)

# %% [markdown]
# # CartPole: Keep the tip of the pole straight

# %%
env= gym.make('CartPole-v1')#creates an instance of the CartPole-v1 environment.
test_env(env)
env.close()

# %% [markdown]
# ### The state
#  The states of the cartpole task will be represented by a vector of four real numbers

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %% [markdown]
# The actions available
# we can perform two actions in this enviroment
#
#       0 Push the cart to the left
#       1 push the cart to the right

# %%
env.action_space
# Out:
# Discrete(2)

# %% [markdown]
# # Acrobot: swing the bar up to a certain height

# %%
env = gym.make('Acrobot-v1')#creates an instance of the Acrobot-v1 environment.
test_env(env)
env.close()

# %% [markdown]
# The state
# the states

# %%
env.observation_space
# Out:
# Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)

# %% [markdown]
# The actions available
#
# we can perform two actions in this enviroment
#
# - 0: Apply +1 torque on the joint between the links
# - 1: Apply -1 torque on the joint between the links

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# # MountainCar : Reach the goal from the bottom of the valley

# %%
env = gym.make('MountainCar-v0') #creates an instance of the MountainCar-v0 environment.
test_env(env)
env.close()

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %% [markdown]
# Actions available:
#
# - 0:accelerate to left
# - 1:don't accelerate
# - 2:accelerate to right

# %%
env.action_space
# Out:
# Discrete(3)

# %% [markdown]
# # Pendulum : swing it and keep it upright

# %%
env = gym.make('Pendulum-v1') #creates an instance of the Pendulum-v1 environment.
test_env(env)
env.close()

# %%
env.observation_space
# Out:
# Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)

# %%
env.action_space
# Out:
# Box(-2.0, 2.0, (1,), float32)
